# %% [markdown]
# # Explore the Pachon / Gemini South DIMM data

# %% [markdown]
# ## Jupyter boilerplate

# %%
# %matplotlib inline
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
import sys
import os
import copy
from collections import namedtuple
from functools import partial
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual
import dateutil
import psycopg2
import colorcet
import cycler
from scipy.constants import golden
from statsmodels.graphics.gofplots import qqplot

from astropy.coordinates import EarthLocation

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

mpl.rcParams['figure.figsize'] = (30, 5)
plt.style.use('ggplot')
BLUE = "#004D99"
RED = "#AF2F2F"
mpl.rcParams["axes.prop_cycle"] = cycler.cycler(
    color=[
        "#002C8C",
        "#AF2F2F",
        "#4C8C2C",
        "#CC8C00",
        "#ABB200",
        "#A500D1",
        "#008498",
        "#00E800",
        "#9FA69C",
        "#01D5E7",
        "#7A5600",
    ]
)
# Out:
# <style>.container { width:90% !important; }</style>

# %%
note_dir = '../figures'
data_dir = '../data'

# %% [markdown]
# ## Load the DIMM data

# %%
dimm = pd.read_hdf(os.path.join(data_dir, 'Pachon_DIMM_to_2019-10-07.h5'))
dimm.head()
# Out:
#                                                time    hr  fwhm    flux  \
# t
# 2004-03-17 02:33:15+00:00 2004-03-17 02:33:15+00:00  4763  0.71  466228
# 2004-03-17 02:34:35+00:00 2004-03-17 02:34:35+00:00  4763  0.74  470195
# 2004-03-17 02:35:42+00:00 2004-03-17 02:35:42+00:00  4763  0.74  460268
# 2004-03-17 02:36:49+00:00 2004-03-17 02:36:49+00:00  4763  0.75  462758
# 2004-03-17 02:37:58+00:00 2004-03-17 02:37:58+00:00  4763  0.72  457338
#
#                            strehlL  strehlR           mjd  month  year  \
# t
# 2004-03-17 02:33:15+00:00      0.0      0.0  53081.106424      3  2004
# 2004-03-17 02:34:35+00:00      0.0      0.0  53081.107350      3  2004
# 2004-03-17 02:35:42+00:00      0.0      0.0  53081.108125      3  2004
# 2004-03-17 02:36:49+00:00      0.0      0.0  53081.108900      3  2004
# 2004-03-17 02:37:58+00:00      0.0      0.0  53081.109699      3  2004
#
#                            data_month  night     am  strehl  strehl_frac_diff  \
# t
# 2004-03-17 02:33:15+00:00           3  53081  False     0.0               NaN
# 2004-03-17 02:34:35+00:00           3  53081  False     0.0               NaN
# 2004-03-17 02:35:42+00:00           3  53081  False     0.0               NaN
# 2004-03-17 02:36:49+00:00           3  53081  False     0.0               NaN
# 2004-03-17 02:37:58+00:00           3  53081  False     0.0               NaN
#
#                                  r0    log_r0    solar_zd
# t
# 2004-03-17 02:33:15+00:00  0.142352 -0.846637  134.478719
# 2004-03-17 02:34:35+00:00  0.136581 -0.864611  134.707136
# 2004-03-17 02:35:42+00:00  0.136581 -0.864611  134.897625
# 2004-03-17 02:36:49+00:00  0.134760 -0.870440  135.087365
# 2004-03-17 02:37:58+00:00  0.140375 -0.852711  135.281977

# %%
dimm.tail()
# Out:
#                                                time    hr   fwhm   flux  \
# t
# 2019-10-07 09:27:01+00:00 2019-10-07 09:27:01+00:00  2294  0.546  16451
# 2019-10-07 09:28:04+00:00 2019-10-07 09:28:04+00:00  2294  0.574  15658
# 2019-10-07 09:29:07+00:00 2019-10-07 09:29:07+00:00  2294  0.481  16000
# 2019-10-07 09:30:10+00:00 2019-10-07 09:30:10+00:00  2294  0.528  16457
# 2019-10-07 09:31:07+00:00 2019-10-07 09:31:07+00:00  2294  0.478  16484
#
#                            strehlL  strehlR           mjd  month  year  \
# t
# 2019-10-07 09:27:01+00:00    0.318    0.519  58763.393762     10  2019
# 2019-10-07 09:28:04+00:00    0.314    0.515  58763.394491     10  2019
# 2019-10-07 09:29:07+00:00    0.311    0.534  58763.395220     10  2019
# 2019-10-07 09:30:10+00:00    0.321    0.523  58763.395949     10  2019
# 2019-10-07 09:31:07+00:00    0.303    0.526  58763.396609     10  2019
#
#                            data_month  night    am  strehl  strehl_frac_diff  \
# t
# 2019-10-07 09:27:01+00:00         190  58763  True  0.4185          0.480287
# 2019-10-07 09:28:04+00:00         190  58763  True  0.4145          0.484922
# 2019-10-07 09:29:07+00:00         190  58763  True  0.4225          0.527811
# 2019-10-07 09:30:10+00:00         190  58763  True  0.4220          0.478673
# 2019-10-07 09:31:07+00:00         190  58763  True  0.4145          0.537998
#
#                                  r0    log_r0    solar_zd
# t
# 2019-10-07 09:27:01+00:00  0.185109 -0.732571  100.877917
# 2019-10-07 09:28:04+00:00  0.176080 -0.754291  100.656648
# 2019-10-07 09:29:07+00:00  0.210124 -0.677524  100.435255
# 2019-10-07 09:30:10+00:00  0.191420 -0.718013  100.213740
# 2019-10-07 09:31:07+00:00  0.211443 -0.674807  100.013217

# %% [markdown]
# ## Load DECam seeing data for comparison

# %%
decam = pd.read_hdf(os.path.join(data_dir, 'decam_seeing.h5'))

# %% [markdown]
# Get rid of bad values

# %%
decam = decam[~ np.isnan(decam.seeing)]

# %% [markdown]
# We want a `data_month` value that corresponds to the DIMM data month, no the DECam data month.

# %%
decam['data_month'] = 12*(decam.year - dimm.index.year.min()) + decam.month

# %%
decam = decam[decam.year<2020]

# %%
decam.head()
# Out:
#                                       id                             date  \
# t
# 2012-12-12 01:27:21.949000+00:00  160509 2012-12-12 01:27:21.949000+00:00
# 2012-12-12 02:01:01.099401+00:00  160522 2012-12-12 02:01:01.099401+00:00
# 2012-12-12 02:23:28.874983+00:00  160541 2012-12-12 02:23:28.874983+00:00
# 2012-12-12 02:24:56.874680+00:00  160542 2012-12-12 02:24:56.874680+00:00
# 2012-12-12 02:26:25.908967+00:00  160543 2012-12-12 02:26:25.908967+00:00
#
#                                  filter  airmass  qc_fwhm      corr  \
# t
# 2012-12-12 01:27:21.949000+00:00      r     1.23     1.09  0.927534
# 2012-12-12 02:01:01.099401+00:00      r     1.48     1.37  0.826147
# 2012-12-12 02:23:28.874983+00:00      g     1.62     1.57  0.739190
# 2012-12-12 02:24:56.874680+00:00      g     1.63     1.61  0.736354
# 2012-12-12 02:26:25.908967+00:00      g     1.64     1.76  0.733459
#
#                                            mjd  month  year  night    seeing  \
# t
# 2012-12-12 01:27:21.949000+00:00  56273.060671     12  2012  56273  0.920832
# 2012-12-12 02:01:01.099401+00:00  56273.084041     12  2012  56273  1.069023
# 2012-12-12 02:23:28.874983+00:00  56273.099640     12  2012  56273  1.111837
# 2012-12-12 02:24:56.874680+00:00  56273.100658     12  2012  56273  1.138280
# 2012-12-12 02:26:25.908967+00:00  56273.101689     12  2012  56273  1.247979
#
#                                   data_month
# t
# 2012-12-12 01:27:21.949000+00:00         108
# 2012-12-12 02:01:01.099401+00:00         108
# 2012-12-12 02:23:28.874983+00:00         108
# 2012-12-12 02:24:56.874680+00:00         108
# 2012-12-12 02:26:25.908967+00:00         108

# %% [markdown]
# ## Calculate monthly statistics

# %%
def make_quant_fn(q):
    fn = partial(np.quantile, q=q)
    fn.__name__ = f'{int(100*q)}%'
    return fn

data_stats = [make_quant_fn(q) for q in (0.05, 0.25, 0.5, 0.75, 0.95)]

dimm_bymonth = dimm.groupby('data_month').agg({'month': 'median',
                                             'year': 'median',
                                             'time': ['min', 'max'],
                                             'fwhm': data_stats,
                                             'r0': data_stats,
                                             'log_r0': data_stats,
                                             'strehl': data_stats})
dimm_bymonth.head()
# Out:
#             month   year                      time                            \
#            median median                       min                       max
# data_month
# 3               3   2004 2004-03-17 02:33:15+00:00 2004-03-26 10:10:39+00:00
# 4               4   2004 2004-04-08 00:13:59+00:00 2004-04-21 03:20:35+00:00
# 5               5   2004 2004-05-06 22:47:26+00:00 2004-05-29 09:11:58+00:00
# 6               6   2004 2004-06-03 23:46:06+00:00 2004-06-30 23:59:40+00:00
# 7               7   2004 2004-07-01 00:00:51+00:00 2004-07-20 04:09:19+00:00
#
#              fwhm                                r0  ...    log_r0            \
#                5%   25%   50%   75%   95%        5%  ...        5%       25%
# data_month                                           ...
# 3           0.520  0.61  0.69  0.78  1.01  0.100069  ... -0.999700 -0.887473
# 4           0.540  0.70  0.87  1.05  1.34  0.075425  ... -1.122484 -1.016568
# 5           0.579  0.85  1.05  1.29  1.94  0.052098  ... -1.283181 -1.105968
# 6           0.580  1.04  1.53  1.96  2.43  0.041592  ... -1.380985 -1.287635
# 7           0.510  0.82  1.06  1.28  1.66  0.060885  ... -1.215487 -1.102589
#
#                                           strehl                         \
#                  50%       75%       95%      5%    25%     50%     75%
# data_month
# 3          -0.834228 -0.780709 -0.711382  0.0000  0.000  0.0000  0.0000
# 4          -0.934898 -0.840477 -0.727773  0.0000  0.000  0.0000  0.0000
# 5          -1.016568 -0.924798 -0.758051  0.1975  0.282  0.3530  0.4125
# 6          -1.180070 -1.012412 -0.758807  0.2275  0.263  0.2995  0.3600
# 7          -1.020685 -0.909193 -0.702949  0.2540  0.348  0.4080  0.4435
#
#
#                 95%
# data_month
# 3           0.00000
# 4           0.00000
# 5           0.47255
# 6           0.43250
# 7           0.48000
#
# [5 rows x 24 columns]

# %% [markdown]
# Now do something similar for DECam seeing data:

# %%
decam_bymonth = decam.groupby('data_month').agg({'month': 'median',
                                                 'year': 'median',
                                                 'date': ['min', 'max'],
                                                 'seeing': data_stats})
decam_bymonth.head()
# Out:
#             month   year                             date  \
#            median median                              min
# data_month
# 108            12   2012 2012-12-12 01:27:21.949000+00:00
# 109             1   2013 2013-01-04 01:25:43.723141+00:00
# 110             2   2013 2013-02-01 01:23:15.438657+00:00
# 111             3   2013 2013-03-01 00:34:34.971388+00:00
# 112             4   2013 2013-04-04 08:26:58.960567+00:00
#
#                                                seeing                      \
#                                         max        5%       25%       50%
# data_month
# 108        2012-12-30 08:23:47.079431+00:00  0.667860  0.769029  0.864609
# 109        2013-01-31 04:51:44.455514+00:00  0.708133  0.830107  0.970538
# 110        2013-02-28 08:23:49.007649+00:00  0.683199  0.784648  0.900333
# 111        2013-03-30 07:52:24.880645+00:00  0.612124  0.713090  0.801397
# 112        2013-04-30 08:09:13.727428+00:00  0.615141  0.759326  0.871920
#
#
#                  75%       95%
# data_month
# 108         0.985510  1.231771
# 109         1.161220  1.475472
# 110         1.062820  1.362078
# 111         0.922648  1.137759
# 112         1.077033  1.637947

# %% [markdown]
# ## Plot monthly statistics by month

# %%
fig, ax = plt.subplots(1, figsize=(15, 5))
col = 'strehl'

for _, dimm_bymonth_seq in dimm_bymonth.groupby('data_month'):
    df = pd.concat([
        dimm_bymonth_seq.set_index(('time', 'min')).copy(),
        dimm_bymonth_seq.set_index(('time', 'max')).copy()
    ]).sort_index()

    ax.fill_between(df.index, df[(col, '5%')], df[(col, '95%')], color='k', alpha=0.10)
    ax.fill_between(df.index, df[(col, '25%')], df[(col, '75%')], color='k', alpha=0.15)
    ax.plot(df.index, df[(col, '50%')], color='k')
    ax.set_ylabel(col)
    
ax.xaxis.set_major_locator(mpl.dates.YearLocator())
ax.xaxis.set_major_formatter(mpl.dates.DateFormatter('%Y'))
ax.xaxis.set_minor_locator(mpl.dates.MonthLocator())

ax.set_ylabel("Strehl ratio")
fig.savefig(os.path.join(note_dir, 'monthly_strehl_vs_year.png'), pdi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(1, figsize=(15, 5))
col = 'fwhm'

for _, dimm_bymonth_seq in dimm_bymonth.groupby('data_month'):
    df = pd.concat([
        dimm_bymonth_seq.set_index(('time', 'min')).copy(),
        dimm_bymonth_seq.set_index(('time', 'max')).copy()
    ]).sort_index()

    ax.fill_between(df.index, df[(col, '5%')], df[(col, '95%')], color='k', alpha=0.10)
    ax.fill_between(df.index, df[(col, '25%')], df[(col, '75%')], color='k', alpha=0.15)
    ax.plot(df.index, df[(col, '50%')], color='k')
    ax.set_ylabel(col)
    
ax.xaxis.set_major_locator(mpl.dates.YearLocator())
ax.xaxis.set_major_formatter(mpl.dates.DateFormatter('%Y'))
ax.xaxis.set_minor_locator(mpl.dates.MonthLocator())

ax.set_yscale('log')
ax.set_yticks(list(np.arange(0.4, 1.0, 0.1)) + list(np.arange(1.0, 2.0, 0.2)) + list(np.arange(2.0, 4.0, 0.4)))
ax.get_yaxis().set_major_formatter(mpl.ticker.ScalarFormatter())

ax.set_ylabel("FWHM (asec, 500nm, zenith)")
fig.savefig(os.path.join(note_dir, 'monthly_dimm_vs_year.png'), pdi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(1, figsize=(15, 5))
col = 'fwhm'

for _, dimm_bymonth_seq in dimm_bymonth.groupby('data_month'):
    df = pd.concat([
        dimm_bymonth_seq.set_index(('time', 'min')).copy(),
        dimm_bymonth_seq.set_index(('time', 'max')).copy()
    ]).sort_index()

    ax.fill_between(df.index, df[(col, '5%')], df[(col, '95%')], color='k', alpha=0.10)
    ax.fill_between(df.index, df[(col, '25%')], df[(col, '75%')], color='k', alpha=0.15)
    ax.plot(df.index, df[(col, '50%')], color='k')
    ax.set_ylabel(col)
    
ax.xaxis.set_major_locator(mpl.dates.YearLocator())
ax.xaxis.set_major_formatter(mpl.dates.DateFormatter('%Y'))
ax.xaxis.set_minor_locator(mpl.dates.MonthLocator())

ax.set_ylim(0, 3.0)

ax.set_ylabel("FWHM (asec, 500nm, zenith)")
# Out:
# Text(0, 0.5, 'FWHM (asec, 500nm, zenith)')

# %%
fig, ax = plt.subplots(1, figsize=(15, 5))
col = 'fwhm'

for _, dimm_bymonth_seq in dimm_bymonth.groupby('data_month'):
    df = pd.concat([
        dimm_bymonth_seq.set_index(('time', 'min')).copy(),
        dimm_bymonth_seq.set_index(('time', 'max')).copy()
    ]).sort_index()

    ax.fill_between(df.index, df[(col, '5%')], df[(col, '95%')], color='k', alpha=0.10)
    ax.fill_between(df.index, df[(col, '25%')], df[(col, '75%')], color='k', alpha=0.15)
    ax.plot(df.index, df[(col, '50%')], color='k')
    ax.set_ylabel(col)
    
ax.xaxis.set_major_locator(mpl.dates.YearLocator())
ax.xaxis.set_major_formatter(mpl.dates.DateFormatter('%Y'))
ax.xaxis.set_minor_locator(mpl.dates.MonthLocator())

ax.set_yscale('log')
df = pd.concat([
    decam_bymonth.set_index(('date', 'min')).copy(),
    decam_bymonth.set_index(('date', 'max')).copy()
    ]).sort_index()
ax.plot(df.index, df[('seeing', '5%')], color='orange', alpha=0.6)
ax.plot(df.index, df[('seeing', '25%')], color='red', alpha=0.5)
ax.plot(df.index, df[('seeing', '50%')], color='red', alpha=0.6, linewidth=3)
ax.plot(df.index, df[('seeing', '75%')], color='red', alpha=0.5)
ax.plot(df.index, df[('seeing', '95%')], color='orange', alpha=0.6)

ax.set_yscale('log')
ax.set_yticks(list(np.arange(0.4, 1.0, 0.1)) + list(np.arange(1.0, 2.0, 0.2)) + list(np.arange(2.0, 4.0, 0.4)))
ax.get_yaxis().set_major_formatter(mpl.ticker.ScalarFormatter())

ax.set_ylabel("FWHM (asec, 500nm, zenith)")
ax.set_title(r"DIMM (Kolmogorov) and DECam seeing quantiles by month")
fig.savefig(os.path.join(note_dir, 'monthly_dimm_vs_year.png'), pdi=300, bbox_inches='tight')

# %% [markdown]
# ## Plot DIMM against DECam seeing statistics

# %% [markdown]
# Combine the DIMM and DECam data frames:

# %%
seeing_bymonth = dimm_bymonth.merge(decam_bymonth)
seeing_bymonth.head()
# Out:
#    month   year                      time                            fwhm  \
#   median median                       min                       max    5%
# 0     12   2012 2012-12-02 01:17:48+00:00 2012-12-31 08:51:49+00:00  0.49
# 1      1   2013 2013-01-03 00:40:56+00:00 2013-01-31 06:25:39+00:00  0.57
# 2      2   2013 2013-02-01 00:30:47+00:00 2013-02-28 09:47:09+00:00  0.49
# 3      3   2013 2013-03-01 00:02:51+00:00 2013-03-19 09:54:09+00:00  0.56
# 4      4   2013 2013-04-07 00:03:51+00:00 2013-04-30 02:59:57+00:00  0.58
#
#                                  r0  ...  strehl                    \
#     25%   50%   75%   95%        5%  ...     50%      75%      95%
# 0  0.62  0.74  0.89  1.16  0.087129  ...  0.7395  0.78600  0.83725
# 1  0.70  0.82  0.97  1.33  0.075992  ...  0.7580  0.82450  0.87150
# 2  0.63  0.76  0.92  1.26  0.080214  ...  0.6705  0.77050  0.85580
# 3  0.68  0.79  0.90  1.12  0.090241  ...  0.6845  0.77750  0.84300
# 4  0.73  0.85  0.98  1.23  0.082171  ...  0.5525  0.61975  0.74585
#
#                               date                                     seeing  \
#                                min                              max        5%
# 0 2012-12-12 01:27:21.949000+00:00 2012-12-30 08:23:47.079431+00:00  0.667860
# 1 2013-01-04 01:25:43.723141+00:00 2013-01-31 04:51:44.455514+00:00  0.708133
# 2 2013-02-01 01:23:15.438657+00:00 2013-02-28 08:23:49.007649+00:00  0.683199
# 3 2013-03-01 00:34:34.971388+00:00 2013-03-30 07:52:24.880645+00:00  0.612124
# 4 2013-04-04 08:26:58.960567+00:00 2013-04-30 08:09:13.727428+00:00  0.615141
#
#
#         25%       50%       75%       95%
# 0  0.769029  0.864609  0.985510  1.231771
# 1  0.830107  0.970538  1.161220  1.475472
# 2  0.784648  0.900333  1.062820  1.362078
# 3  0.713090  0.801397  0.922648  1.137759
# 4  0.759326  0.871920  1.077033  1.637947
#
# [5 rows x 31 columns]

# %% [markdown]
# Plot the DIMM statistics againt the DECam ones, color coding the points by the Strehl ratio.

# %%
fig, axes = plt.subplots(2, 3, figsize=(19, 10))
quants = ('5%', '25%', '50%', '75%', '95%')

all_seeing_ticks = np.concatenate([np.arange(0.4, 1.0, 0.1), np.arange(1.0, 2.0, 0.2), np.arange(2.0, 4.0, 0.4)])
for ax, quant in zip(axes.flatten()[:len(quants)], quants):
    seeing_bymonth.plot.scatter(('seeing', quant), ('fwhm', quant), c=('strehl', '50%'), cmap=colorcet.cm.rainbow_r, ax=ax)
    match_values = seeing_bymonth[('fwhm', quant)].sort_values()
    ax.plot(match_values, match_values, c='b')

    min_seeing = min([seeing_bymonth[('seeing', quant)].min(),
                      seeing_bymonth[('fwhm', quant)].min()])
    max_seeing = max([seeing_bymonth[('seeing', quant)].max(),
                      seeing_bymonth[('fwhm', quant)].max()])
    
    seeing_ticks = all_seeing_ticks[ (all_seeing_ticks > min_seeing) & (all_seeing_ticks < max_seeing) ]
    
    ax.set_ylabel(f'DIMM, {quant}')
    ax.set_yscale('log')
    ax.set_yticks(seeing_ticks)
    ax.get_yaxis().set_major_formatter(mpl.ticker.ScalarFormatter())
    ax.minorticks_off()
    
    ax.set_xlabel(f'DECam, {quant}')
    ax.set_xscale('log')
    ax.set_xticks(seeing_ticks)
    ax.get_xaxis().set_major_formatter(mpl.ticker.ScalarFormatter())
    ax.minorticks_off()
    
axes[1, 2].axis('off')
plt.tight_layout()
# Out:
# /data/des91.b/data/neilsen/anaconda/envs/ehn38_91/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:420: FutureWarning: Converting timezone-aware DatetimeArray to timezone-naive ndarray with 'datetime64[ns]' dtype. In the future, this will return an ndarray with 'object' dtype where each element is a 'pandas.Timestamp' with the correct 'tz'.
# 	To accept the future behavior, pass 'dtype=object'.
# 	To keep the old behavior, pass 'dtype="datetime64[ns]"'.
#   numeric_data[col] = np.asarray(numeric_data[col])
# /data/des91.b/data/neilsen/anaconda/envs/ehn38_91/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:420: FutureWarning: Converting timezone-aware DatetimeArray to timezone-naive ndarray with 'datetime64[ns]' dtype. In the future, this will return an ndarray with 'object' dtype where each element is a 'pandas.Timestamp' with the correct 'tz'.
# 	To accept the future behavior, pass 'dtype=object'.
# 	To keep the old behavior, pass 'dtype="datetime64[ns]"'.
#   numeric_data[col] = np.asarray(numeric_data[col])
# /data/des91.b/data/neilsen/anaconda/envs/ehn38_91/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:420: FutureWarning: Converting timezone-aware DatetimeArray to timezone-naive ndarray with 'datetime64[ns]' dtype. In the future, this will return an ndarray with 'object' dtype where each element is a 'pandas.Timestamp' with the correct 'tz'.
# 	To accept the future behavior, pass 'dtype=object'.
# 	To keep the old behavior, pass 'dtype="datetime64[ns]"'.
#   numeric_data[col] = np.asarray(numeric_data[col])
# /data/des91.b/data/neilsen/anaconda/envs/ehn38_91/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:420: FutureWarning: Converting timezone-aware DatetimeArray to timezone-naive ndarray with 'datetime64[ns]' dtype. In the future, this will return an ndarray with 'object' dtype where each element is a 'pandas.Timestamp' with the correct 'tz'.
# 	To accept the future behavior, pass 'dtype=object'.
# 	To keep the old behavior, pass 'dtype="datetime64[ns]"'.
#   numeric_data[col] = np.asarray(numeric_data[col])
# /data/des91.b/data/neilsen/anaconda/envs/ehn38_91/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:420: FutureWarning: Converting timezone-aware DatetimeArray to timezone-naive ndarray with 'datetime64[ns]' dtype. In the future, this will return an ndarray with 'object' dtype where each element is a 'pandas.Timestamp' with the correct 'tz'.
# 	To accept the future behavior, pass 'dtype=object'.
# 	To keep the old behavior, pass 'dtype="datetime64[ns]"'.
#   numeric_data[col] = np.asarray(numeric_data[col])

# %%
fig, ax = plt.subplots(1, figsize=(14, 5))
quants = ('5%', '25%', '50%', '75%', '95%')

quant_marks = {'5%': "o",
               '25%': 7,
               '50%': "*",
               '75%': 6,
               '95%': "o"}

size_scale = 10
seeing_ticks = np.concatenate([np.arange(0.4, 1.0, 0.1), np.arange(1.0, 2.0, 0.2), np.arange(2.0, 4.0, 0.4)])
seeing_bymonth['median DIMM Strehl ratio'] = seeing_bymonth[('strehl', '50%')]
seeing_bymonth.plot.scatter(('seeing', quants[0]), ('fwhm', quants[0]), c='median DIMM Strehl ratio',
                            s=size_scale, marker=quant_marks[quants[0]],
                            cmap=colorcet.cm.rainbow_r,
                            label=quants[0],
                            ax=ax)
for s, quant in enumerate(quants[1:]):
    ax.scatter(seeing_bymonth[('seeing', quant)], seeing_bymonth[('fwhm', quant)],
               c=seeing_bymonth[('strehl', '50%')],
               s=(s+1)*size_scale, marker=quant_marks[quant], label=quant,
               cmap=colorcet.cm.rainbow_r)

match_values = np.arange(0.4, 3.7, 0.1)
ax.plot(match_values, match_values, c='b')    
ax.set_ylabel('DIMM seeing (asec FWHM, 500nm, zenith)')
ax.set_yscale('log')
ax.set_yticks(seeing_ticks)
ax.get_yaxis().set_major_formatter(mpl.ticker.ScalarFormatter())
ax.minorticks_off()
    
ax.set_xlabel('DECam seeing (asec FWHM, 500nm, zenith)')
ax.set_xscale('log')
ax.set_xticks(seeing_ticks)
ax.get_xaxis().set_major_formatter(mpl.ticker.ScalarFormatter())
ax.minorticks_off()
    
ax.legend()
#plt.tight_layout()
ax.set_title(r"DIMM (Kolmogorov) vs. DECam seeing monthly quantiles")
fig.savefig(os.path.join(note_dir, 'dimm_vs_decam.png'), pdi=300, bbox_inches='tight')
# Out:
# /data/des91.b/data/neilsen/anaconda/envs/ehn38_91/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:420: FutureWarning: Converting timezone-aware DatetimeArray to timezone-naive ndarray with 'datetime64[ns]' dtype. In the future, this will return an ndarray with 'object' dtype where each element is a 'pandas.Timestamp' with the correct 'tz'.
# 	To accept the future behavior, pass 'dtype=object'.
# 	To keep the old behavior, pass 'dtype="datetime64[ns]"'.
#   numeric_data[col] = np.asarray(numeric_data[col])

# %%
seeing_bymonth.head()
# Out:
#    month   year                      time                            fwhm  \
#   median median                       min                       max    5%
# 0     12   2012 2012-12-02 01:17:48+00:00 2012-12-31 08:51:49+00:00  0.49
# 1      1   2013 2013-01-03 00:40:56+00:00 2013-01-31 06:25:39+00:00  0.57
# 2      2   2013 2013-02-01 00:30:47+00:00 2013-02-28 09:47:09+00:00  0.49
# 3      3   2013 2013-03-01 00:02:51+00:00 2013-03-19 09:54:09+00:00  0.56
# 4      4   2013 2013-04-07 00:03:51+00:00 2013-04-30 02:59:57+00:00  0.58
#
#                                  r0  ...   strehl           \
#     25%   50%   75%   95%        5%  ...      75%      95%
# 0  0.62  0.74  0.89  1.16  0.087129  ...  0.78600  0.83725
# 1  0.70  0.82  0.97  1.33  0.075992  ...  0.82450  0.87150
# 2  0.63  0.76  0.92  1.26  0.080214  ...  0.77050  0.85580
# 3  0.68  0.79  0.90  1.12  0.090241  ...  0.77750  0.84300
# 4  0.73  0.85  0.98  1.23  0.082171  ...  0.61975  0.74585
#
#                               date                                     seeing  \
#                                min                              max        5%
# 0 2012-12-12 01:27:21.949000+00:00 2012-12-30 08:23:47.079431+00:00  0.667860
# 1 2013-01-04 01:25:43.723141+00:00 2013-01-31 04:51:44.455514+00:00  0.708133
# 2 2013-02-01 01:23:15.438657+00:00 2013-02-28 08:23:49.007649+00:00  0.683199
# 3 2013-03-01 00:34:34.971388+00:00 2013-03-30 07:52:24.880645+00:00  0.612124
# 4 2013-04-04 08:26:58.960567+00:00 2013-04-30 08:09:13.727428+00:00  0.615141
#
#                                           median DIMM Strehl ratio
#         25%       50%       75%       95%
# 0  0.769029  0.864609  0.985510  1.231771                   0.7395
# 1  0.830107  0.970538  1.161220  1.475472                   0.7580
# 2  0.784648  0.900333  1.062820  1.362078                   0.6705
# 3  0.713090  0.801397  0.922648  1.137759                   0.6845
# 4  0.759326  0.871920  1.077033  1.637947                   0.5525
#
# [5 rows x 32 columns]

# %% [markdown]
# It does not look like the match between the DIMM and DECam would be improved by filtering on the Strehl ratio.

# %% [markdown]
# ## Look at statistics by night

# %%
dimm_bynight = dimm.groupby('night').agg({'month': 'median',
                                             'year': 'median',
                                             'fwhm': 'median',
                                             'strehl': 'median'})
dimm_bynight.rename(columns={'fwhm': 'dimm'}, inplace=True)

decam_bynight = decam.groupby('night').agg({'month': 'median',
                                            'year': 'median',
                                            'seeing': 'median'})
decam_bynight.rename(columns={'seeing': 'decam'}, inplace=True)

seeing_bynight = dimm_bynight.merge(decam_bynight)
seeing_bynight['strehl_bin'] = pd.cut(seeing_bynight['strehl'], np.arange(0.05, 0.95, 0.05))

seeing_bynight['seeing_ratio'] = seeing_bynight.decam/seeing_bynight.dimm
seeing_bynight['frac_diff'] = (seeing_bynight.decam-seeing_bynight.dimm)/seeing_bynight.decam
seeing_bynight.head()
# Out:
#    month  year  dimm   strehl     decam   strehl_bin  seeing_ratio  frac_diff
# 0     12  2012  0.57  0.79625  1.164803  (0.75, 0.8]      2.043514   0.510647
# 1     12  2012  0.57  0.79625  0.837504  (0.75, 0.8]      1.469305   0.319406
# 2     12  2012  0.57  0.79625  0.913835  (0.75, 0.8]      1.603220   0.376255
# 3     12  2012  0.57  0.79625  0.832839  (0.75, 0.8]      1.461122   0.315594
# 4     12  2012  0.57  0.79625  0.797762  (0.75, 0.8]      1.399582   0.285501

# %%
fig, ax = plt.subplots(1, figsize=(14, 5))
col = 'strehl_bin'
seeing_bynight.boxplot('decam', by=col, whis=[5, 95], showfliers=False, ax=ax)
ax.set_yscale('log')
ax.set_yticks(list(np.arange(0.6, 1.6, 0.1))+list(np.arange(1.6, 2.0, 0.2)))
ax.get_yaxis().set_major_formatter(mpl.ticker.ScalarFormatter())
ax.minorticks_off()
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
        
ax.set_ylabel("DECam seeing (zenith, 500nm) (asec)")
ax.set_xlabel("Nightly median Strehl ratio")
ax.set_title("")
fig.suptitle("")
# Out:
# Text(0.5, 0.98, '')

# %%
fig, ax = plt.subplots(1, figsize=(14, 5))
col = 'strehl_bin'
seeing_bynight.boxplot('frac_diff', by=col, whis=[5, 95], showfliers=False, ax=ax)
ax.set_xlabel("Strehl ratio")
ax.set_ylabel("Fractional difference in PSF width")
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
        
ax.set_ylabel("(DECam-DIMM)/DECam")
ax.set_xlabel("Nightly median Strehl ratio")
ax.set_title("Fractional difference between DIMM and DECam seeing estimates")
fig.suptitle("")
# Out:
# Text(0.5, 0.98, '')

# %% [markdown]
# ## Statistics by hour

# %%
dimm['mjd_hour'] = np.floor(dimm.mjd*24)/24
dimm_byhour = dimm.groupby('mjd_hour').agg({'month': 'median',
                                             'year': 'median',
                                             'fwhm': 'median',
                                             'strehlL': 'median',
                                             'strehlR': 'median',
                                             'strehl': 'median'})
dimm_byhour.rename(columns={'fwhm': 'dimm'}, inplace=True)
print('Created dimm_byhour')

decam['mjd_hour'] = np.floor(decam.mjd*24)/24
decam_byhour = decam.groupby('mjd_hour').agg({'month': 'median',
                                            'year': 'median',
                                            'seeing': 'median'})
decam_byhour.rename(columns={'seeing': 'decam'}, inplace=True)
print('Created decam_byhour')

seeing_byhour = dimm_byhour.merge(decam_byhour, left_index=True, right_index=True)
print('Finished merge')
seeing_byhour['strehl_bin'] = pd.cut(seeing_byhour['strehl'], np.arange(0.05, 0.95, 0.05))
seeing_byhour['strehlL_bin'] = pd.cut(seeing_byhour['strehlL'], np.arange(0.05, 0.95, 0.05))
seeing_byhour['strehlR_bin'] = pd.cut(seeing_byhour['strehlR'], np.arange(0.05, 0.95, 0.05))
print('Created sthehl_bin')

seeing_byhour['seeing_ratio'] = seeing_byhour.decam/seeing_byhour.dimm
seeing_byhour['frac_diff'] = (seeing_byhour.decam-seeing_byhour.dimm)/seeing_byhour.decam
seeing_byhour.head()
# Out:
# Created dimm_byhour
# Created decam_byhour
# Finished merge
# Created sthehl_bin
#               month_x  year_x   dimm  strehlL  strehlR   strehl  month_y  \
# mjd_hour
# 56273.041667       12    2012  0.800   0.7940   0.7860  0.79000       12
# 56273.083333       12    2012  0.825   0.8040   0.7590  0.78150       12
# 56273.125000       12    2012  0.775   0.7935   0.7075  0.74650       12
# 56273.166667       12    2012  0.920   0.7300   0.6280  0.68000       12
# 56273.208333       12    2012  0.825   0.6885   0.5860  0.63875       12
#
#               year_y     decam   strehl_bin  strehlL_bin  strehlR_bin  \
# mjd_hour
# 56273.041667    2012  0.920832  (0.75, 0.8]  (0.75, 0.8]  (0.75, 0.8]
# 56273.083333    2012  1.111837  (0.75, 0.8]  (0.8, 0.85]  (0.75, 0.8]
# 56273.125000    2012  1.167106  (0.7, 0.75]  (0.75, 0.8]  (0.7, 0.75]
# 56273.166667    2012  1.175897  (0.65, 0.7]  (0.7, 0.75]  (0.6, 0.65]
# 56273.208333    2012  1.132057  (0.6, 0.65]  (0.65, 0.7]  (0.55, 0.6]
#
#               seeing_ratio  frac_diff
# mjd_hour
# 56273.041667      1.151040   0.131220
# 56273.083333      1.347681   0.257984
# 56273.125000      1.505943   0.335964
# 56273.166667      1.278149   0.217619
# 56273.208333      1.372190   0.271238

# %%
fig, ax = plt.subplots(1, figsize=(14, 5))
col = 'strehl_bin'
seeing_byhour.boxplot('decam', by=col, whis=[5, 95], showfliers=False, ax=ax)
ax.set_yscale('log')
ax.set_yticks(list(np.arange(0.6, 1.6, 0.1))+list(np.arange(1.6, 2.0, 0.2)))
ax.get_yaxis().set_major_formatter(mpl.ticker.ScalarFormatter())
ax.minorticks_off()
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
        
ax.set_ylabel("DECam seeing (zenith, 500nm) (asec)")
ax.set_xlabel("Hourly median Strehl ratio")
ax.set_title("")
fig.suptitle("")
# Out:
# Text(0.5, 0.98, '')

# %%
fig, ax = plt.subplots(1, figsize=(14, 5))
col = 'strehl_bin'
seeing_byhour.boxplot('frac_diff', by=col, whis=[5, 95], showfliers=False, ax=ax)
ax.set_xlabel("Strehl ratio")
ax.set_ylabel("Fractional difference in PSF width")
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
        
ax.set_ylabel("(DECam-DIMM)/DECam")
ax.set_xlabel("Hourly median Strehl ratio")
ax.set_title("Fractional difference between DIMM and DECam seeing estimates")
fig.suptitle("")
# Out:
# Text(0.5, 0.98, '')

# %%
fig, axes = plt.subplots(2, figsize=(14, 10), sharex=True)
col = 'strehl_bin'

ax = axes[0]
seeing_byhour.boxplot('frac_diff', by=col, whis=[5, 95], showfliers=False, ax=ax)
ax.set_xlabel("Strehl ratio")
ax.set_ylabel("Fractional difference in PSF width")
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
        
ax.set_ylabel("(DECam-DIMM)/DECam seeing")
ax.set_xlabel("")
ax.set_title("")

ax = axes[1]
seeing_byhour.boxplot('decam', by=col, whis=[5, 95], showfliers=False, ax=ax)
ax.set_yscale('log')
ax.set_yticks(list(np.arange(0.6, 1.6, 0.1))+list(np.arange(1.6, 2.0, 0.2)))
ax.get_yaxis().set_major_formatter(mpl.ticker.ScalarFormatter())
ax.minorticks_off()
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
        
ax.set_ylabel("DECam seeing (zenith, 500nm) (asec)")
ax.set_xlabel("Hourly median Strehl ratio")
ax.set_title("")
fig.suptitle("")

plt.tight_layout()
fig.savefig(os.path.join(note_dir, 'strehl_boxplots.png'), pdi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(1, figsize=(14, 5))
seeing_byhour.strehl.hist(bins=np.arange(0,1,0.025), histtype='step', color='r', ax=ax)
seeing_byhour.strehl.hist(bins=np.arange(0,1,0.025), alpha=0.2, color='r', ax=ax)
_ = ax.set_xticks(np.arange(0, 0.95, 0.1))
fig.savefig(os.path.join(note_dir, 'strehl_hist.png'), pdi=300, bbox_inches='tight')

# %%
len(seeing_byhour.query('strehl<0.25'))/len(seeing_byhour)
# Out:
# 0.031043005437469105

# %%
full_seeing_byhour = seeing_byhour.copy()

# %% [markdown]
# ## Look at Strehl ratio and other features

# %%
fig, ax = plt.subplots(1, figsize=(8, 8))
_ = ax.hist2d(dimm.solar_zd, dimm.strehl, bins=100)

# %%
site_longitude_deg = EarthLocation.of_site('Cerro Pachon').lon.deg
site_night_shift = (180.0 + site_longitude_deg)/360.0
time_of_night = dimm.mjd + site_night_shift - np.floor(dimm.mjd + site_night_shift)
fig, ax = plt.subplots(1, figsize=(20, 5))
_ = ax.hist2d(time_of_night , dimm.strehl, bins=100)

# %% [markdown]
# ## How do the Strehl ratios of the two different images compare?

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 8))
axes[0].hist2d(dimm.strehlL, dimm.strehlR, bins=400, cmap='inferno_r', cmin=1, cmax=1000)
axes[1].hist2d(dimm.strehlL, dimm.strehlR, bins=400, norm=mpl.colors.LogNorm(), cmap='inferno_r')
True
# Out:
# /data/des91.b/data/neilsen/anaconda/envs/ehn38_91/lib/python3.8/site-packages/matplotlib/axes/_axes.py:7080: RuntimeWarning: invalid value encountered in greater
#   h[h > cmax] = None
# True

# %% [markdown]
# # Plot nightly seeing

# %%
def plot_night_seeing(df, night, fig, axes):
    night_df = df[df.night == night]
    
    night_df.plot(y='log_r0', drawstyle='steps-mid',ax=axes)
    axes.set_ylim(axes.get_ylim()[::-1])

    # Add an axes with the DIMM measured seeing on the right
    right_axes = axes.twinx()
    night_df.plot(y='log_r0', drawstyle='steps-mid', ax=right_axes)

    seeing_ticks = np.concatenate((np.arange(0.4, 2.0, 0.2), np.arange(2.0, 4.0, 0.4)), axis=0)
    logr0_ticks = np.log10(0.98*5e-7/np.radians(seeing_ticks/(60*60)))
    right_axes.set_yticks(logr0_ticks)
    right_axes.set_yticklabels(f'{s:2.1f}"' for s in seeing_ticks)
    right_axes.set_ylabel('seeing')

    right_axes.set_ylim(axes.get_ylim())
    right_axes.grid(False)
    axes.set_ylabel("$\log(r_{0})$, $r_{0}$ in meters")
    
    axes.xaxis.set_major_formatter(mpl.dates.DateFormatter('%H:%m:%SZ'))
    
    axes.legend().set_visible(False)
    right_axes.legend().set_visible(False)
    
    axes.set_title('Night MJD %d' % night)
    return fig, axes

# %%
# Explicitly setting a seed make reproducability easier without having to rerun the whole notebook
np.random.seed(4861)

mpl.rcParams['figure.figsize'] = (15, 15)
fig, axes = plt.subplots(3,1)

# Pick some random nights during which the DIMM ran most of the night
sample_nights = dimm.groupby('night').agg({'fwhm': 'count'}).query('fwhm>600').sample(len(axes.flatten())).index.values
for ax, sample_night in zip(axes.flatten(), np.sort(sample_nights)):
    plot_night_seeing(dimm, sample_night, fig, ax)
    
axes[2].set_xlabel("")
plt.tight_layout()
fig.savefig(os.path.join(note_dir, 'random_nights_dimm'), pdi=300, bbox_inches='tight')

# %%
decam.head()
# Out:
#                                       id                             date  \
# t
# 2012-12-12 01:27:21.949000+00:00  160509 2012-12-12 01:27:21.949000+00:00
# 2012-12-12 02:01:01.099401+00:00  160522 2012-12-12 02:01:01.099401+00:00
# 2012-12-12 02:23:28.874983+00:00  160541 2012-12-12 02:23:28.874983+00:00
# 2012-12-12 02:24:56.874680+00:00  160542 2012-12-12 02:24:56.874680+00:00
# 2012-12-12 02:26:25.908967+00:00  160543 2012-12-12 02:26:25.908967+00:00
#
#                                  filter  airmass  qc_fwhm      corr  \
# t
# 2012-12-12 01:27:21.949000+00:00      r     1.23     1.09  0.927534
# 2012-12-12 02:01:01.099401+00:00      r     1.48     1.37  0.826147
# 2012-12-12 02:23:28.874983+00:00      g     1.62     1.57  0.739190
# 2012-12-12 02:24:56.874680+00:00      g     1.63     1.61  0.736354
# 2012-12-12 02:26:25.908967+00:00      g     1.64     1.76  0.733459
#
#                                            mjd  month  year  night    seeing  \
# t
# 2012-12-12 01:27:21.949000+00:00  56273.060671     12  2012  56273  0.920832
# 2012-12-12 02:01:01.099401+00:00  56273.084041     12  2012  56273  1.069023
# 2012-12-12 02:23:28.874983+00:00  56273.099640     12  2012  56273  1.111837
# 2012-12-12 02:24:56.874680+00:00  56273.100658     12  2012  56273  1.138280
# 2012-12-12 02:26:25.908967+00:00  56273.101689     12  2012  56273  1.247979
#
#                                   data_month      mjd_hour
# t
# 2012-12-12 01:27:21.949000+00:00         108  56273.041667
# 2012-12-12 02:01:01.099401+00:00         108  56273.083333
# 2012-12-12 02:23:28.874983+00:00         108  56273.083333
# 2012-12-12 02:24:56.874680+00:00         108  56273.083333
# 2012-12-12 02:26:25.908967+00:00         108  56273.083333

# %%
dimm.head()
# Out:
#                                                time    hr  fwhm    flux  \
# t
# 2004-03-17 02:33:15+00:00 2004-03-17 02:33:15+00:00  4763  0.71  466228
# 2004-03-17 02:34:35+00:00 2004-03-17 02:34:35+00:00  4763  0.74  470195
# 2004-03-17 02:35:42+00:00 2004-03-17 02:35:42+00:00  4763  0.74  460268
# 2004-03-17 02:36:49+00:00 2004-03-17 02:36:49+00:00  4763  0.75  462758
# 2004-03-17 02:37:58+00:00 2004-03-17 02:37:58+00:00  4763  0.72  457338
#
#                            strehlL  strehlR           mjd  month  year  \
# t
# 2004-03-17 02:33:15+00:00      0.0      0.0  53081.106424      3  2004
# 2004-03-17 02:34:35+00:00      0.0      0.0  53081.107350      3  2004
# 2004-03-17 02:35:42+00:00      0.0      0.0  53081.108125      3  2004
# 2004-03-17 02:36:49+00:00      0.0      0.0  53081.108900      3  2004
# 2004-03-17 02:37:58+00:00      0.0      0.0  53081.109699      3  2004
#
#                            data_month  night     am  strehl  strehl_frac_diff  \
# t
# 2004-03-17 02:33:15+00:00           3  53081  False     0.0               NaN
# 2004-03-17 02:34:35+00:00           3  53081  False     0.0               NaN
# 2004-03-17 02:35:42+00:00           3  53081  False     0.0               NaN
# 2004-03-17 02:36:49+00:00           3  53081  False     0.0               NaN
# 2004-03-17 02:37:58+00:00           3  53081  False     0.0               NaN
#
#                                  r0    log_r0    solar_zd      mjd_hour
# t
# 2004-03-17 02:33:15+00:00  0.142352 -0.846637  134.478719  53081.083333
# 2004-03-17 02:34:35+00:00  0.136581 -0.864611  134.707136  53081.083333
# 2004-03-17 02:35:42+00:00  0.136581 -0.864611  134.897625  53081.083333
# 2004-03-17 02:36:49+00:00  0.134760 -0.870440  135.087365  53081.083333
# 2004-03-17 02:37:58+00:00  0.140375 -0.852711  135.281977  53081.083333

# %%
def plot_night_seeing(df, night, fig, axes):
    night_df = df[df.night == night]
    night_decam_df = decam[np.floor(decam.mjd+0.1)==night]
    
    night_df.plot('time', 'fwhm', drawstyle='steps-mid', ax=axes, label='DIMM')
    night_decam_df.plot('date', 'seeing', drawstyle='steps-mid', ax=axes, label='DECam')

    axes.set_ylabel("Seeing (500nm, zenith), asec")
    axes.set_ylim(0, 2.5)
    axes.set_xlabel(None)
    
    axes.xaxis.set_major_formatter(mpl.dates.DateFormatter('%H:%m:%SZ'))
    
    axes.legend().set_visible(False)
    axes.set_title(' Night MJD %d' % night, loc='left', pad=-20)
    axes.legend()
    return fig, axes

# Explicitly setting a seed make reproducability easier without having to rerun the whole notebook
np.random.seed(4861)
#np.random.seed(6563)

mpl.rcParams['figure.figsize'] = (23, 12)
fig, axes = plt.subplots(3,2, sharey=True)

# Pick some random nights during which the DIMM ran most of the night
dimm_full_nights = set(dimm.groupby('night').agg({'fwhm': 'count'}).query('fwhm>600').index.values)

decam['night'] = np.floor(decam.mjd+0.2).astype(int)
decam_full_nights = set(decam.groupby('night').agg({'qc_fwhm': 'count'}).query('qc_fwhm>200').index.values)

both_nights = dimm_full_nights.intersection(decam_full_nights)

nplots = len(axes.flatten())
sample_nights = pd.Series(np.array(list(both_nights))).sample(nplots)
for ax, sample_night in zip(axes.flatten(), np.sort(sample_nights)):
    plot_night_seeing(dimm, sample_night, fig, ax)
    
plt.tight_layout()

# %%
decam.head(9)
# Out:
#                                       id                             date  \
# t
# 2012-12-12 01:27:21.949000+00:00  160509 2012-12-12 01:27:21.949000+00:00
# 2012-12-12 02:01:01.099401+00:00  160522 2012-12-12 02:01:01.099401+00:00
# 2012-12-12 02:23:28.874983+00:00  160541 2012-12-12 02:23:28.874983+00:00
# 2012-12-12 02:24:56.874680+00:00  160542 2012-12-12 02:24:56.874680+00:00
# 2012-12-12 02:26:25.908967+00:00  160543 2012-12-12 02:26:25.908967+00:00
# 2012-12-12 02:35:28.170500+00:00  160547 2012-12-12 02:35:28.170500+00:00
# 2012-12-12 02:36:47.147376+00:00  160548 2012-12-12 02:36:47.147376+00:00
# 2012-12-12 02:38:05.758107+00:00  160549 2012-12-12 02:38:05.758107+00:00
# 2012-12-12 02:39:24.072408+00:00  160550 2012-12-12 02:39:24.072408+00:00
#
#                                  filter  airmass  qc_fwhm      corr  \
# t
# 2012-12-12 01:27:21.949000+00:00      r     1.23     1.09  0.927534
# 2012-12-12 02:01:01.099401+00:00      r     1.48     1.37  0.826147
# 2012-12-12 02:23:28.874983+00:00      g     1.62     1.57  0.739190
# 2012-12-12 02:24:56.874680+00:00      g     1.63     1.61  0.736354
# 2012-12-12 02:26:25.908967+00:00      g     1.64     1.76  0.733459
# 2012-12-12 02:35:28.170500+00:00      i     1.71     1.64  0.788855
# 2012-12-12 02:36:47.147376+00:00      i     1.72     1.57  0.785843
# 2012-12-12 02:38:05.758107+00:00      i     1.73     1.44  0.782821
# 2012-12-12 02:39:24.072408+00:00      r     1.74     1.45  0.749295
#
#                                            mjd  month  year  night    seeing  \
# t
# 2012-12-12 01:27:21.949000+00:00  56273.060671     12  2012  56273  0.920832
# 2012-12-12 02:01:01.099401+00:00  56273.084041     12  2012  56273  1.069023
# 2012-12-12 02:23:28.874983+00:00  56273.099640     12  2012  56273  1.111837
# 2012-12-12 02:24:56.874680+00:00  56273.100658     12  2012  56273  1.138280
# 2012-12-12 02:26:25.908967+00:00  56273.101689     12  2012  56273  1.247979
# 2012-12-12 02:35:28.170500+00:00  56273.107965     12  2012  56273  1.244067
# 2012-12-12 02:36:47.147376+00:00  56273.108879     12  2012  56273  1.182008
# 2012-12-12 02:38:05.758107+00:00  56273.109789     12  2012  56273  1.070807
# 2012-12-12 02:39:24.072408+00:00  56273.110695     12  2012  56273  1.032832
#
#                                   data_month      mjd_hour
# t
# 2012-12-12 01:27:21.949000+00:00         108  56273.041667
# 2012-12-12 02:01:01.099401+00:00         108  56273.083333
# 2012-12-12 02:23:28.874983+00:00         108  56273.083333
# 2012-12-12 02:24:56.874680+00:00         108  56273.083333
# 2012-12-12 02:26:25.908967+00:00         108  56273.083333
# 2012-12-12 02:35:28.170500+00:00         108  56273.083333
# 2012-12-12 02:36:47.147376+00:00         108  56273.083333
# 2012-12-12 02:38:05.758107+00:00         108  56273.083333
# 2012-12-12 02:39:24.072408+00:00         108  56273.083333

# %% [markdown]
# ## Plot DIMM against Gemini South IQ

# %%
gemini = pd.read_excel(os.path.join(data_dir, 'GeminiS_IQData.xlsx'), 'ALL DATA', header=8, parse_dates=[[0,1]])
gemini['data_month'] = 12*(gemini['YEAR'] - np.min(dimm.year)) + gemini['MONTH']
gemini = gemini[gemini['IQ 500 ZENITH'] > 0]
gemini = gemini.set_index('DATE_UT', drop=False).tz_localize('UTC')
gemini['mjd'] = gemini.index.to_julian_date()-2400000.5

# %%
gemini.head(1).T
# Out:
# DATE_UT                                      2003-01-21 01:05:58+00:00
# DATE_UT                                            2003-01-21 01:05:58
# DAYCOUNT                                                       1116.05
# INSTRUMENT                                                      GMOS-S
# GMOS-S                                                               1
# F2                                                                 NaN
# OBSERVATION                                       GS-CAL20030121-6-001
# AIRMASS                                                          1.624
# FILTER                                                               g
# WAVELENGTH                                                         475
# FILENAME                                           S20030121S0049.fits
# OBJECT                                                           RU149
# IQ BAND                                                             70
# BG BAND                                                             50
# BRIGHTNESS                                                     21.1997
# BRIGHTNESS ERROR                                              0.729822
# IQ                                                               1.075
# IQ ERROR                                                          0.09
# IQ ZENITH                                                     0.803631
# IQ ZENITH ERROR                                              0.0672808
# IQ 500 ZENITH                                                 0.795429
# IQ 500 ZENITH ERROR                                          0.0665941
# ELLIPTICITY                                                      0.121
# ELLIPTICITY ERROR                                                0.069
# EXTINCTION                                                         NaN
# EXTINCTION ERROR                                                   NaN
# GMOS SEEING                                                   0.795429
# F2 SEEING                                                           -1
# RANK IQ 500 ZENITH   if(u10>0,IF(OR(AA10>0,AB10>0),($D$5-SUMPRODUCT...
# MONTH                                                                1
# YEAR                                                              2003
# data_month                                                         -11
# mjd                                                              52660

# %% [markdown]
# ## Compare monthly stats

# %%
gemini_bymonth = gemini.groupby('data_month').agg({'MONTH': 'median',
                                                   'YEAR': 'median',
                                                   'DATE_UT': ['min', 'max'],
                                                   'IQ 500 ZENITH': data_stats})

# %% [markdown]
# Exclude pre-DIMM data

# %%
gemini_bymonth = gemini_bymonth.query('data_month>0')

# %%
def calc_FWHM_vK(fwhm_dimm, outer_scale=30, wavelength=5.0e-7):
    r0 = 0.98*wavelength/(np.radians(fwhm_dimm/(60*60)))
    fwhm = fwhm_dimm * np.sqrt(1.0 - 2.183*np.power(r0/outer_scale, 0.356) )
    return fwhm

# %%
quants = ('5%', '25%', '50%', '75%', '95%')
for quant in quants:
    seeing_bymonth[('dimm_vk30', quant)] = calc_FWHM_vK(seeing_bymonth[('fwhm', quant)])
    dimm_bymonth[('dimm_vk30', quant)] = calc_FWHM_vK(dimm_bymonth[('fwhm', quant)])

# %%
gemini['IQ 500 ZENITH'].describe()
# Out:
# count    70193.000000
# mean         0.813028
# std          0.313900
# min          0.073232
# 25%          0.602243
# 50%          0.756350
# 75%          0.958504
# max         10.730337
# Name: IQ 500 ZENITH, dtype: float64

# %%
fig, ax = plt.subplots(1, figsize=(15, 5))
col = 'dimm_vk30'

for _, dimm_bymonth_seq in dimm_bymonth.groupby('data_month'):
    df = pd.concat([
        dimm_bymonth_seq.set_index(('time', 'min')).copy(),
        dimm_bymonth_seq.set_index(('time', 'max')).copy()
    ]).sort_index()

    ax.fill_between(df.index, df[(col, '5%')], df[(col, '95%')], color='k', alpha=0.10)
    ax.fill_between(df.index, df[(col, '25%')], df[(col, '75%')], color='k', alpha=0.15)
    ax.plot(df.index, df[(col, '50%')], color='k')
    ax.set_ylabel(col)
    
ax.xaxis.set_major_locator(mpl.dates.YearLocator())
ax.xaxis.set_major_formatter(mpl.dates.DateFormatter('%Y'))
ax.xaxis.set_minor_locator(mpl.dates.MonthLocator())

ax.set_yscale('log')
df = pd.concat([
    gemini_bymonth.set_index(('DATE_UT', 'min')).copy(),
    gemini_bymonth.set_index(('DATE_UT', 'max')).copy()
    ]).sort_index()
ax.plot(df.index, df[('IQ 500 ZENITH', '5%')], color='orange', alpha=0.6)
ax.plot(df.index, df[('IQ 500 ZENITH', '25%')], color='red', alpha=0.5)
ax.plot(df.index, df[('IQ 500 ZENITH', '50%')], color='red', alpha=0.6, linewidth=3)
ax.plot(df.index, df[('IQ 500 ZENITH', '75%')], color='red', alpha=0.5)
ax.plot(df.index, df[('IQ 500 ZENITH', '95%')], color='orange', alpha=0.6)

ax.set_yscale('log')
ax.set_yticks(list(np.arange(0.2, 1.0, 0.1)) + list(np.arange(1.0, 2.0, 0.2)) + list(np.arange(2.0, 4.0, 0.4)))
ax.get_yaxis().set_major_formatter(mpl.ticker.ScalarFormatter())

ax.set_ylabel("FWHM (asec, 500nm, zenith, L=30m)")
ax.set_title(r"DIMM (von Kármán, L=30m) and Gemini S IQ seeing quantiles by month")
fig.savefig(os.path.join(note_dir, 'monthly_gemini_dimm_vs_year.png'), pdi=300, bbox_inches='tight')

# %%
seeing_bymonth['data_month'] = 12*(seeing_bymonth[('year', 'median')] - np.min(dimm.year)) + seeing_bymonth[('month', 'median')]
seeing_bymonth.set_index('data_month', inplace=True)
seeing_bymonth = seeing_bymonth.merge(gemini_bymonth[['IQ 500 ZENITH']], left_index=True, right_index=True)
seeing_bymonth.head()
# Out:
#             month   year                      time                            \
#            median median                       min                       max
# data_month
# 108            12   2012 2012-12-02 01:17:48+00:00 2012-12-31 08:51:49+00:00
# 109             1   2013 2013-01-03 00:40:56+00:00 2013-01-31 06:25:39+00:00
# 110             2   2013 2013-02-01 00:30:47+00:00 2013-02-28 09:47:09+00:00
# 111             3   2013 2013-03-01 00:02:51+00:00 2013-03-19 09:54:09+00:00
# 112             4   2013 2013-04-07 00:03:51+00:00 2013-04-30 02:59:57+00:00
#
#             fwhm                                r0  ... dimm_vk30            \
#               5%   25%   50%   75%   95%        5%  ...        5%       25%
# data_month                                          ...
# 108         0.49  0.62  0.74  0.89  1.16  0.087129  ...  0.388680  0.503309
# 109         0.57  0.70  0.82  0.97  1.33  0.075992  ...  0.459068  0.574435
# 110         0.49  0.63  0.76  0.92  1.26  0.080214  ...  0.388680  0.512178
# 111         0.56  0.68  0.79  0.90  1.12  0.090241  ...  0.450241  0.556618
# 112         0.58  0.73  0.85  0.98  1.23  0.082171  ...  0.467902  0.601204
#
#                                          IQ 500 ZENITH                      \
#                  50%       75%       95%            5%       25%       50%
# data_month
# 108         0.610138  0.744723  0.989180      0.519206  0.686138  0.829925
# 109         0.681788  0.816892  1.144211      0.499804  0.608536  0.728491
# 110         0.628021  0.771757  1.080285      0.491931  0.627989  0.734697
# 111         0.654883  0.753731  0.952815      0.481132  0.598745  0.732047
# 112         0.708734  0.825930  1.052926      0.454924  0.587494  0.757649
#
#
#                  75%       95%
# data_month
# 108         0.966617  1.274569
# 109         0.889815  1.253760
# 110         0.910790  1.114325
# 111         0.883594  1.118179
# 112         0.883565  1.108722
#
# [5 rows x 42 columns]

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
quants = ('5%', '25%', '50%', '75%', '95%')

all_seeing_ticks = np.concatenate([np.arange(0.4, 1.0, 0.1), np.arange(1.0, 2.0, 0.2), np.arange(2.0, 4.0, 0.4)])
for ax, quant in zip(axes.flatten()[:len(quants)], quants):
    seeing_bymonth.plot.scatter(('IQ 500 ZENITH', quant), ('dimm_vk30', quant), c=('strehl', '50%'), cmap=colorcet.cm.rainbow_r, ax=ax)
    match_values = seeing_bymonth[('fwhm', quant)].sort_values()
    ax.plot(match_values, match_values, c='b')

    min_seeing = min([seeing_bymonth[('IQ 500 ZENITH', quant)].min(),
                      seeing_bymonth[('fwhm', quant)].min()])
    max_seeing = max([seeing_bymonth[('IQ 500 ZENITH', quant)].max(),
                      seeing_bymonth[('fwhm', quant)].max()])
    
    seeing_ticks = all_seeing_ticks[ (all_seeing_ticks > min_seeing) & (all_seeing_ticks < max_seeing) ]
    
    ax.set_ylabel(f'DIMM, {quant}')
    ax.set_yscale('log')
    ax.set_yticks(seeing_ticks)
    ax.get_yaxis().set_major_formatter(mpl.ticker.ScalarFormatter())
    ax.minorticks_off()
    
    ax.set_xlabel(f'Gemini, {quant}')
    ax.set_xscale('log')
    ax.set_xticks(seeing_ticks)
    ax.get_xaxis().set_major_formatter(mpl.ticker.ScalarFormatter())
    ax.minorticks_off()
    
axes[1, 2].axis('off')
plt.tight_layout()
# Out:
# /data/des91.b/data/neilsen/anaconda/envs/ehn38_91/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:420: FutureWarning: Converting timezone-aware DatetimeArray to timezone-naive ndarray with 'datetime64[ns]' dtype. In the future, this will return an ndarray with 'object' dtype where each element is a 'pandas.Timestamp' with the correct 'tz'.
# 	To accept the future behavior, pass 'dtype=object'.
# 	To keep the old behavior, pass 'dtype="datetime64[ns]"'.
#   numeric_data[col] = np.asarray(numeric_data[col])
# /data/des91.b/data/neilsen/anaconda/envs/ehn38_91/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:420: FutureWarning: Converting timezone-aware DatetimeArray to timezone-naive ndarray with 'datetime64[ns]' dtype. In the future, this will return an ndarray with 'object' dtype where each element is a 'pandas.Timestamp' with the correct 'tz'.
# 	To accept the future behavior, pass 'dtype=object'.
# 	To keep the old behavior, pass 'dtype="datetime64[ns]"'.
#   numeric_data[col] = np.asarray(numeric_data[col])
# /data/des91.b/data/neilsen/anaconda/envs/ehn38_91/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:420: FutureWarning: Converting timezone-aware DatetimeArray to timezone-naive ndarray with 'datetime64[ns]' dtype. In the future, this will return an ndarray with 'object' dtype where each element is a 'pandas.Timestamp' with the correct 'tz'.
# 	To accept the future behavior, pass 'dtype=object'.
# 	To keep the old behavior, pass 'dtype="datetime64[ns]"'.
#   numeric_data[col] = np.asarray(numeric_data[col])
# /data/des91.b/data/neilsen/anaconda/envs/ehn38_91/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:420: FutureWarning: Converting timezone-aware DatetimeArray to timezone-naive ndarray with 'datetime64[ns]' dtype. In the future, this will return an ndarray with 'object' dtype where each element is a 'pandas.Timestamp' with the correct 'tz'.
# 	To accept the future behavior, pass 'dtype=object'.
# 	To keep the old behavior, pass 'dtype="datetime64[ns]"'.
#   numeric_data[col] = np.asarray(numeric_data[col])
# /data/des91.b/data/neilsen/anaconda/envs/ehn38_91/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:420: FutureWarning: Converting timezone-aware DatetimeArray to timezone-naive ndarray with 'datetime64[ns]' dtype. In the future, this will return an ndarray with 'object' dtype where each element is a 'pandas.Timestamp' with the correct 'tz'.
# 	To accept the future behavior, pass 'dtype=object'.
# 	To keep the old behavior, pass 'dtype="datetime64[ns]"'.
#   numeric_data[col] = np.asarray(numeric_data[col])

# %%
fig, ax = plt.subplots(1, figsize=(14, 5))
quants = ('5%', '25%', '50%', '75%', '95%')

quant_marks = {'5%': "o",
               '25%': 7,
               '50%': "*",
               '75%': 6,
               '95%': "o"}

size_scale = 10
seeing_ticks = np.concatenate([np.arange(0.4, 1.0, 0.1), np.arange(1.0, 2.2, 0.2)])
seeing_bymonth['median DIMM Strehl ratio'] = seeing_bymonth[('strehl', '50%')]

seeing_bymonth.plot.scatter(('dimm_vk30', quants[0]), ('IQ 500 ZENITH', quants[0]), c='median DIMM Strehl ratio',
                            s=size_scale, marker=quant_marks[quants[0]],
                            cmap=colorcet.cm.rainbow_r,
                            label=quants[0],
                            ax=ax)
for s, quant in enumerate(quants[1:]):
    ax.scatter(seeing_bymonth[('dimm_vk30', quant)], seeing_bymonth[('IQ 500 ZENITH', quant)], 
               c=seeing_bymonth[('strehl', '50%')],
               s=(s+1)*size_scale, marker=quant_marks[quant], label=quant,
               cmap=colorcet.cm.rainbow_r)

match_values = np.arange(0.4, 2.1, 0.1)
ax.plot(match_values, match_values, c='b')    
ax.set_xlabel('DIMM seeing\n(asec FWHM, 500nm, zenith, L=30m)')
ax.set_xscale('log')
ax.set_xticks(seeing_ticks)
ax.get_xaxis().set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set_ylim(0.3, 2.0)
ax.minorticks_off()
    
ax.set_ylabel('Gemini IQ (asec FWHM, 500nm, zenith)')
ax.set_yscale('log')
ax.set_yticks(seeing_ticks)
ax.get_yaxis().set_major_formatter(mpl.ticker.ScalarFormatter())
ax.minorticks_off()
    
ax.legend()
#plt.tight_layout()
ax.set_title(r"Gemini S IQ vs. DIMM (von Kármán, L=30m) seeing monthly quantiles")
fig.savefig(os.path.join(note_dir, 'geminiIQ_vs_dimm.png'), pdi=300, bbox_inches='tight')
# Out:
# /data/des91.b/data/neilsen/anaconda/envs/ehn38_91/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:420: FutureWarning: Converting timezone-aware DatetimeArray to timezone-naive ndarray with 'datetime64[ns]' dtype. In the future, this will return an ndarray with 'object' dtype where each element is a 'pandas.Timestamp' with the correct 'tz'.
# 	To accept the future behavior, pass 'dtype=object'.
# 	To keep the old behavior, pass 'dtype="datetime64[ns]"'.
#   numeric_data[col] = np.asarray(numeric_data[col])

# %%
seeing_byhour.head()
# Out:
#               month_x  year_x   dimm  strehlL  strehlR   strehl  month_y  \
# mjd_hour
# 56273.041667       12    2012  0.800   0.7940   0.7860  0.79000       12
# 56273.083333       12    2012  0.825   0.8040   0.7590  0.78150       12
# 56273.125000       12    2012  0.775   0.7935   0.7075  0.74650       12
# 56273.166667       12    2012  0.920   0.7300   0.6280  0.68000       12
# 56273.208333       12    2012  0.825   0.6885   0.5860  0.63875       12
#
#               year_y     decam   strehl_bin  strehlL_bin  strehlR_bin  \
# mjd_hour
# 56273.041667    2012  0.920832  (0.75, 0.8]  (0.75, 0.8]  (0.75, 0.8]
# 56273.083333    2012  1.111837  (0.75, 0.8]  (0.8, 0.85]  (0.75, 0.8]
# 56273.125000    2012  1.167106  (0.7, 0.75]  (0.75, 0.8]  (0.7, 0.75]
# 56273.166667    2012  1.175897  (0.65, 0.7]  (0.7, 0.75]  (0.6, 0.65]
# 56273.208333    2012  1.132057  (0.6, 0.65]  (0.65, 0.7]  (0.55, 0.6]
#
#               seeing_ratio  frac_diff
# mjd_hour
# 56273.041667      1.151040   0.131220
# 56273.083333      1.347681   0.257984
# 56273.125000      1.505943   0.335964
# 56273.166667      1.278149   0.217619
# 56273.208333      1.372190   0.271238

# %%
gemini['mjd_hour'] = np.floor(gemini.mjd*24)/24
gemini_byhour = gemini.groupby('mjd_hour').agg({'MONTH': 'median',
                                                'YEAR': 'median',
                                                'IQ 500 ZENITH': 'median'})
gemini_byhour.rename(columns={'IQ 500 ZENITH': 'gemini'}, inplace=True)
print('Created gemini_byhour')

seeing_byhour = seeing_byhour.merge(gemini_byhour, left_index=True, right_index=True)
seeing_byhour['gem_seeing_ratio'] = seeing_byhour.gemini/seeing_byhour.dimm
seeing_byhour['gem_frac_diff'] = (seeing_byhour.gemini-seeing_byhour.dimm)/seeing_byhour.gemini
df.head()
# Out:
# Created gemini_byhour
#                                         DATE_UT                          \
#                                             max                     min
# 2004-01-19 00:23:16.200 2004-01-24 09:26:31.600                     NaT
# 2004-01-24 09:26:31.600                     NaT 2004-01-19 00:23:16.200
# 2004-02-16 03:56:24.800 2004-02-29 01:32:29.000                     NaT
# 2004-02-29 01:32:29.000                     NaT 2004-02-16 03:56:24.800
# 2004-03-18 01:12:10.900 2004-03-28 09:26:02.500                     NaT
#
#                         IQ 500 ZENITH                                          \
#                                   25%        5%       50%       75%       95%
# 2004-01-19 00:23:16.200      0.550320  0.492339  0.632464  0.754038  0.964213
# 2004-01-24 09:26:31.600      0.550320  0.492339  0.632464  0.754038  0.964213
# 2004-02-16 03:56:24.800      0.541036  0.469241  0.660741  0.842879  1.021363
# 2004-02-29 01:32:29.000      0.541036  0.469241  0.660741  0.842879  1.021363
# 2004-03-18 01:12:10.900      0.464193  0.395571  0.539859  0.690761  0.989443
#
#                          MONTH   YEAR
#                         median median
# 2004-01-19 00:23:16.200      1   2004
# 2004-01-24 09:26:31.600      1   2004
# 2004-02-16 03:56:24.800      2   2004
# 2004-02-29 01:32:29.000      2   2004
# 2004-03-18 01:12:10.900      3   2004

# %%
seeing_byhour['dimm_vk30'] = calc_FWHM_vK(seeing_byhour.dimm)
seeing_byhour['gem_vk30_ratio'] = seeing_byhour.gemini/seeing_byhour.dimm_vk30
seeing_byhour['gem_vk30_frac_diff'] = (seeing_byhour.gemini-seeing_byhour.dimm_vk30)/seeing_byhour.gemini

# %%
fig, axes = plt.subplots(2, figsize=(14, 10), sharex=True)
col = 'strehl_bin'

ax = axes[0]
seeing_byhour.boxplot('gem_vk30_frac_diff', by=col, whis=[5, 95], showfliers=False, ax=ax)
ax.set_xlabel("Strehl ratio")
ax.set_ylabel("Fractional difference in PSF width")
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
        
ax.set_ylabel("(Gemini-DIMM)/Gemini seeing")
ax.set_xlabel("")
ax.set_title("")

ax = axes[1]
seeing_byhour.boxplot('gemini', by=col, whis=[5, 95], showfliers=False, ax=ax)
ax.set_yscale('log')
ax.set_yticks(list(np.arange(0.6, 1.6, 0.1))+list(np.arange(1.6, 2.0, 0.2)))
ax.get_yaxis().set_major_formatter(mpl.ticker.ScalarFormatter())
ax.minorticks_off()
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
        
ax.set_ylabel("Gemini seeing (zenith, 500nm) (asec)")
ax.set_xlabel("Hourly median Strehl ratio")
ax.set_title("")
fig.suptitle("")

plt.tight_layout()
fig.savefig(os.path.join(note_dir, 'gemini_strehl_boxplots.png'), pdi=300, bbox_inches='tight')

# %% [markdown]
# Look at von Karman seeing instead.

# %%
def fade_cmap(cmap, alpha_frac=0.2):
    cmap = copy.deepcopy(cmap)
    ncolors = cmap.N
    cmap_colors = cmap(np.arange(ncolors))
    alpha_cut = np.floor(ncolors*alpha_frac).astype(int)
    cmap_colors[:, -1] = 1
    cmap_colors[:alpha_cut, -1] = np.arange(alpha_cut)/alpha_cut
    cmap = mpl.colors.ListedColormap(cmap_colors)
    return cmap

# %%
fig, ax = plt.subplots(1, figsize=(8.5, 7))
seeing_ticks = np.concatenate([np.arange(0.2, 1.0, 0.1), np.arange(1.0, 2.0, 0.2), np.arange(2.0, 4.0, 0.4)])
seeing_ticklabels = ['%4.2f"' % s for s in seeing_ticks]
cmap = fade_cmap(mpl.cm.viridis_r)
seeing_byhour.plot(kind='hexbin',
                   x='dimm_vk30', y='gemini',
                   xscale='log', yscale='log',
                   gridsize=30,
                   cmap=cmap,
                   ax=ax)
ax.plot([seeing_ticks.min(), seeing_ticks.max()],
        [seeing_ticks.min(), seeing_ticks.max()],
        color='r'
       )
ax.set_xlabel('DIMM transformed to von Karman (outer scale=30m)')
ax.set_xticks(seeing_ticks)
ax.set_xticklabels(seeing_ticklabels, rotation='vertical')
ax.set_ylabel("Gemini IQ 500 ZENITH")
ax.set_yticks(seeing_ticks)
ax.set_yticklabels(seeing_ticklabels)
plt.tight_layout()
fig.savefig(os.path.join(note_dir, 'geminiIQ_vs_dimm_hexbin.png'), pdi=300, bbox_inches='tight')
None

# %%
fig, ax = plt.subplots(1, figsize=(8.5, 7))
seeing_ticks = np.concatenate([np.arange(0.2, 1.0, 0.1), np.arange(1.0, 2.0, 0.2), np.arange(2.0, 4.0, 0.4)])
seeing_ticklabels = ['%4.2f"' % s for s in seeing_ticks]

ax.hist2d(seeing_byhour.dimm_vk30, seeing_byhour.gemini,
                   bins=100,
                   cmap=colorcet.cm.bgyw_r)
ax.set_xscale('log')
ax.set_yscale('log')
ax.plot([seeing_ticks.min(), seeing_ticks.max()],
        [seeing_ticks.min(), seeing_ticks.max()],
        color='r'
       )
ax.set_xlabel('DIMM transformed to von Karman (outer scale=30m)')
ax.set_xticks(seeing_ticks)
ax.set_xticklabels(seeing_ticklabels, rotation='vertical')
ax.set_ylabel("Gemini IQ 500 ZENITH")
ax.set_yticks(seeing_ticks)
ax.set_yticklabels(seeing_ticklabels)
plt.tight_layout()
None

# %%
fig, axes = plt.subplots(2, figsize=(14, 10), sharex=True)
col = 'strehl_bin'

ax = axes[0]
seeing_byhour.boxplot('gem_vk30_frac_diff', by=col, whis=[5, 95], showfliers=False, ax=ax)
ax.set_xlabel("Strehl ratio")
ax.set_ylabel("Fractional difference in PSF width")
for tick in ax.get_xticklabels():
    tick.set_rotation(45)

ax.set_xlabel("")
ax.set_title("")

ax = axes[1]
seeing_byhour.boxplot('gemini', by=col, whis=[5, 95], showfliers=False, ax=ax)
ax.set_yscale('log')
ax.set_yticks(list(np.arange(0.6, 1.6, 0.1))+list(np.arange(1.6, 2.0, 0.2)))
ax.get_yaxis().set_major_formatter(mpl.ticker.ScalarFormatter())
ax.minorticks_off()
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
        
ax.set_ylabel("Gemini seeing (zenith, 500nm) (asec)")
ax.set_xlabel("Hourly median Strehl ratio")
ax.set_title("")
fig.suptitle("")

plt.tight_layout()
fig.savefig(os.path.join(note_dir, 'gemini_strehl_boxplots.png'), pdi=300, bbox_inches='tight')

# %%
fig, axes = plt.subplots(2, figsize=(14, 10), sharex=True)
col = 'strehl_bin'

ax = axes[0]
seeing_byhour.boxplot('gem_vk30_ratio', by=col, whis=[5, 95], showfliers=False, ax=ax)
ax.set_xlabel("Strehl ratio")
ax.set_ylabel("Gemini IQ FWHM/DIMM FWHM")
for tick in ax.get_xticklabels():
    tick.set_rotation(45)

ax.set_xlabel("")
ax.set_title("")

ax = axes[1]
seeing_byhour.boxplot('gemini', by=col, whis=[5, 95], showfliers=False, ax=ax)
ax.set_yscale('log')
ax.set_yticks(list(np.arange(0.6, 1.6, 0.1))+list(np.arange(1.6, 2.0, 0.2)))
ax.get_yaxis().set_major_formatter(mpl.ticker.ScalarFormatter())
ax.minorticks_off()
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
        
ax.set_ylabel("Gemini seeing (zenith, 500nm) (asec)")
ax.set_xlabel("Hourly median Strehl ratio")
ax.set_title("")
fig.suptitle("")

plt.tight_layout()
fig.savefig(os.path.join(note_dir, 'gemini_strehl_boxplots.png'), pdi=300, bbox_inches='tight')
